# %%
import pandas as pd
from tensorflow import keras
from keras import Sequential, Input
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint

df = pd.read_csv("train.csv")
x = df.iloc[:, 0:6]
y = df.iloc[:, 6]

x = pd.get_dummies(x)
y = pd.get_dummies(y)

model = Sequential()
model.add(Input(shape=(x.shape[1],)))
model.add(Dense(12, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(Dense(20, activation="softmax"))
model.summary()


model.compile(loss="categorical_crossentropy",
 optimizer="adam",
 metrics=["accuracy"])

history = model.fit(x, y, epochs=50, batch_size=5, verbose=2)
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 12)             │           216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 8)              │           104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 20)             │           180 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 500 (1.95 KB)
#  Trainable params: 500 (1.95 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 1600/1600 - 8s - 5ms/step - accuracy: 0.3414 - loss: 8.2329
# Epoch 2/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.7437 - loss: 0.8349
# Epoch 3/50
# 1600/1600 - 10s - 6ms/step - accuracy: 0.9111 - loss: 0.3725
# Epoch 4/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9646 - loss: 0.1679
# Epoch 5/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9831 - loss: 0.0859
# Epoch 6/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9930 - loss: 0.0431
# Epoch 7/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9902 - loss: 0.0396
# Epoch 8/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9883 - loss: 0.0664
# Epoch 9/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9999 - loss: 0.0064
# Epoch 10/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9944 - loss: 0.0246
# Epoch 11/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9980 - loss: 0.0071
# Epoch 12/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9981 - loss: 0.0074
# Epoch 13/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9969 - loss: 0.0144
# Epoch 14/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9973 - loss: 0.0105
# Epoch 15/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9999 - loss: 0.0012
# Epoch 16/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9945 - loss: 0.0303
# Epoch 17/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 5.9249e-04
# Epoch 18/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9983 - loss: 0.0111
# Epoch 19/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9974 - loss: 0.0075
# Epoch 20/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 2.9771e-04
# Epoch 21/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 3.5375e-04
# Epoch 22/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9956 - loss: 0.0398
# Epoch 23/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 2.8979e-04
# Epoch 24/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9996 - loss: 0.0013
# Epoch 25/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9971 - loss: 0.0214
# Epoch 26/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 5.5072e-04
# Epoch 27/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 2.0623e-04
# Epoch 28/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 2.1624e-04
# Epoch 29/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9965 - loss: 0.0246
# Epoch 30/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 1.5069e-04
# Epoch 31/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 1.4687e-04
# Epoch 32/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9975 - loss: 0.0143
# Epoch 33/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 4.6846e-04
# Epoch 34/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 1.4863e-04
# Epoch 35/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 1.1477e-04
# Epoch 36/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9985 - loss: 0.0084
# Epoch 37/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 7.8921e-05
# Epoch 38/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9987 - loss: 0.0061
# Epoch 39/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 6.4777e-05
# Epoch 40/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 6.6917e-05
# Epoch 41/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9985 - loss: 0.0077
# Epoch 42/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 5.5247e-05
# Epoch 43/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 4.1670e-05
# Epoch 44/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9973 - loss: 0.0133
# Epoch 45/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 6.1137e-05
# Epoch 46/50
# 1600/1600 - 10s - 6ms/step - accuracy: 1.0000 - loss: 4.1629e-05
# Epoch 47/50
# 1600/1600 - 5s - 3ms/step - accuracy: 1.0000 - loss: 3.7521e-05
# Epoch 48/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9984 - loss: 0.0072
# Epoch 49/50
# 1600/1600 - 5s - 3ms/step - accuracy: 0.9985 - loss: 0.0084
# Epoch 50/50
# 1600/1600 - 10s - 6ms/step - accuracy: 1.0000 - loss: 1.4551e-04

# %%
import pandas as pd
from tensorflow import keras
from keras import Sequential, Input
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint

df = pd.read_csv("train.csv")
x = df.iloc[:, 0:6]
y = df.iloc[:, 6]

x = pd.get_dummies(x)
y = pd.get_dummies(y)

model = Sequential()
model.add(Input(shape=(x.shape[1],)))
model.add(Dense(32, activation="relu"))
model.add(Dense(16, activation="relu"))
model.add(Dense(20, activation="softmax"))

model.compile(
    loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=0.0007),
    metrics=["accuracy"]
)

history = model.fit(x, y, epochs=100, batch_size=8, verbose=2)
